# %%
target_name = "R3Y3S"
SEED_NUM = "3"
redacted_name = ""

for char in target_name:
    if char in "CharlieKirk":
        redacted_name += SEED_NUM
    else:
        redacted_name += char

print(f"Execution Log: Processing {target_name}...")
print(f"Redacted Output: {redacted_name}")
# Out:
# Execution Log: Processing R3Y3S...
# Redacted Output: R3Y3S

# %%
first_letter = "0"
ascii_val = ord(first_letter)
seed_num = 3
loops = 5 # From Task 14 on page 12

verification_hash = (ascii_val * seed_num) - loops

print(f"ASCII: {ascii_val}, Hash: {verification_hash}")
# Out:
# ASCII: 48, Hash: 139

# %%
corrected_password = "177013"
attempts = 0
user_input = ""

while user_input != corrected_password:
    user_input = input("Enter password: ")
    attempts += 1
    print(f"Attempt {attempts}: You entered '{user_input}'")

print(f"Access Granted in {attempts} attempts.")
# Out:
# Attempt 1: You entered 'h'
# Attempt 2: You entered 'j'
# Attempt 3: You entered '123'
# Attempt 4: You entered '1111'
# Attempt 5: You entered '177013'
# Access Granted in 5 attempts.
